# %% [markdown]
# #Rater like model
# Let's build a simple leak differential system

# %%
#/###################/#
# Config
#

#ImportModules
import ShareYourSystem as SYS

#Debug Mode is True ?
SYS.DebugPrintBool=False

#/###################/#
# Build the model
#

#Define
MyLeaker=SYS.LeakerClass(
    ).mapSet(
        {
        '-Populations':{
            '|Default':{
                'LeakingUnitsInt':2,
                    '-Inputs':{
                        '|Default':{
                            'LeakingWeigthVariable':'#custom:#clock:200*ms:5.*mV*int(t==200*ms)',
                        }
                    },
                '-Interactions':{
                        '|/':{
                            'LeakingWeigthVariable':-1.,
                        }
                    },
                }
            }
        }
    ).leak(
    )

#/###################/#
# Represent the model
#

#print
print('MyLeaker is ')
SYS._print(MyLeaker)
# Out:
# MyLeaker is
# < (LeakerClass), 4569189968 >
#    /{
#    /  '<Base><Instance>BrianedNetworkVariable' : <Network at time t=0. s, containing objects: NeuronGroup(clock=Clock defaultclock: t = 0. s, dt = 100. us, when=start, order=0, name='neurongroup'), StateUpdater(clock=Clock defaultclock: t = 0. s, dt = 100. us, when=groups, order=0, name='neurongroup_stateupdater'), CodeRunner(clock=Clock neurongroup_custom_operation_clock: t = 0. s, dt = 200. ms, when=start, order=0, name='neurongroup_custom_operation'), <StateMonitor, recording ['U'] from neurongroup>, Synapses(clock=Clock defaultclock: t = 0. s, dt = 100. us, when=start, order=0, name='synapses'), SummedVariableUpdater(clock=Clock defaultclock: t = 0. s, dt = 100. us, when=groups, order=-1, name='synapses_summed_variable_J__U_post')>
#    /  '<Spe><Instance>TeamDict' :
#    /   /{
#    /   /  'Populations' : < (LeakersStructurerClass), 4570885264 ^ >
#    /   /   /{
#    /   /   /  '<Spe><Instance>ManagementDict' :
#    /   /   /   /{
#    /   /   /   /  'Default' : < (LeakerClass), 4570885520 ^ >
#    /   /   /   /   /{
#    /   /   /   /   /  '<Base><Instance>BrianedNeurongroupVariable' : NeuronGroup(clock=Clock defaultclock: t = 0. s, dt = 100. us, when=start, order=0, name='neurongroup')
#    /   /   /   /   /  '<New><Instance>LeakedModelStr' : I_Default : volt
#    /   /   /   /   /   /   /J__U : volt
#    /   /   /   /   /   /   /dU/dt=(-U+I_Default+ J__U)/(10.*ms) : volt
#    /   /   /   /   /   /   /
#    /   /   /   /   /  '<Spe><Instance>TeamDict' :
#    /   /   /   /   /   /{
#    /   /   /   /   /   /  'Inputs' : < (LeakersStructurerClass), 4570965456 ^ >
#    /   /   /   /   /   /   /{
#    /   /   /   /   /   /   /  '<Spe><Instance>ManagementDict' :
#    /   /   /   /   /   /   /   /{
#    /   /   /   /   /   /   /   /  'Default' : < (LeakerClass), 4570965584 ^ >
#    /   /   /   /   /   /   /   /   /{
#    /   /   /   /   /   /   /   /   /}
#    /   /   /   /   /   /   /   /}
#    /   /   /   /   /   /   /}
#    /   /   /   /   /   /  'Interactions' : < (LeakersStructurerClass), 4570965520 ^ >
#    /   /   /   /   /   /   /{
#    /   /   /   /   /   /   /  '<Spe><Instance>ManagementDict' :
#    /   /   /   /   /   /   /   /{
#    /   /   /   /   /   /   /   /  '/' : < (LeakerClass), 4570967632 ->4570885520 ^ >
#    /   /   /   /   /   /   /   /   /{
#    /   /   /   /   /   /   /   /   
    500.
)

#/###################/#
# View
#

MyLeaker['/-Populations/|Default'].pyplot();
SYS.matplotlib.pyplot.show()

# %% [markdown]
# #Predicter like model
# The predicter class automatically build some inside structures, like a Sensor population with a Command Input.

# %%
#/###################/#
# Config
#

#ImportModules
import ShareYourSystem as SYS

#Debug Mode is True ?
SYS.DebugPrintBool=False

#/###################/#
# Build the model
#

#Define
MyPredicter=SYS.PredicterClass(
	).predict(
    )

#/###################/#
# Represent the model
#

#print
print('MyLeaker is ')
SYS._print(MyLeaker)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-6a499d2d0e04> in <module>()
#      14
#      15 #Define
# ---> 16 MyPredicter=SYS.PredicterClass(
#      17         ).predict(
#      18     )
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_predict(_InstanceVariable, _JacobianFloatsArray, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Specials/Predicters/Predicter/__init__.pyc in do_predict(self)
#     253
#     254                 #leak
# --> 255                 self.leak()
#     256
#     257         def leakNetwork(self):
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Binder/__init__.pyc in switch_watch_superDo_leak(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Switcher/__init__.pyc in switch(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     269                 _InstanceVariable,
#     270                 *_LiargVariablesList,
# --> 271                 **_KwargVariablesDict
#     272 	)
#     273
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Binder/__init__.pyc in watch_superDo_leak(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Watcher/__init__.pyc in watch(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     105                 _InstanceVariable,
#     106                 *_LiargVariablesList,
# --> 107                 **_KwargVariablesDict
#     108 	)
#     109
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_leak(_InstanceVariable, _UnitsInt, _TimeVariable, _WeigthVariable, _QuantityStr, _MonitorIndexIntsList, _SymbolPrefixStr, _InteractionStr, _TransferVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Recorders/Leaker/__init__.pyc in do_leak(self)
#     276 				],
#     277                                 '#all',
# --> 278                                 _ManagerCommandSetList=['leak','brian']
#     279 			)
#     280
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_structure(_InstanceVariable, _TeamerCommandKeyVariable, _ManagerCommandKeyVariable, _BeforeCommandSetList, _TeamerCommandSetList, _ManagerCommandSetList, _SingPluralVariable, _TagStr, _ClassBool, _FlatBool, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Structurer/__init__.pyc in do_structure(self)
#     259
#     260                 #command
# --> 261                 self.command()
#     262
#     263                 #debug
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_command(_InstanceVariable, _KeyVariable, _SetVariable, _OrderStr, _BeforeWalkRigidBool, _AfterWalkRigidBool, _BeforeSelfRigidBool, _AfterSelfRigidBool, _GetRigidBool, _SetRigidBool, _SetAttrOrCallRigidBool, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in do_command(self)
#     521 					)
#     522                                         else None,
# --> 523                                         self.CommandedValueVariablesList
#     524 				)
#     525
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in <lambda>(_CommanderClass__CommandedValueVariable)
#     518 					if hasattr(
#     519                                                 __CommandedValueVariable,
# --> 520                                                 'command'
#     521 					)
#     522                                         else None,
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_command(_InstanceVariable, _KeyVariable, _SetVariable, _OrderStr, _BeforeWalkRigidBool, _AfterWalkRigidBool, _BeforeSelfRigidBool, _AfterSelfRigidBool, _GetRigidBool, _SetRigidBool, _SetAttrOrCallRigidBool, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in do_command(self)
#     521 					)
#     522                                         else None,
# --> 523                                         self.CommandedValueVariablesList
#     524 				)
#     525
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in <lambda>(_CommanderClass__CommandedValueVariable)
#     518 					if hasattr(
#     519                                                 __CommandedValueVariable,
# --> 520                                                 'command'
#     521 					)
#     522                                         else None,
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_command(_InstanceVariable, _KeyVariable, _SetVariable, _OrderStr, _BeforeWalkRigidBool, _AfterWalkRigidBool, _BeforeSelfRigidBool, _AfterSelfRigidBool, _GetRigidBool, _SetRigidBool, _SetAttrOrCallRigidBool, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in do_command(self)
#     521 					)
#     522                                         else None,
# --> 523                                         self.CommandedValueVariablesList
#     524 				)
#     525
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in <lambda>(_CommanderClass__CommandedValueVariable)
#     518 					if hasattr(
#     519                                                 __CommandedValueVariable,
# --> 520                                                 'command'
#     521 					)
#     522                                         else None,
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_command(_InstanceVariable, _KeyVariable, _SetVariable, _OrderStr, _BeforeWalkRigidBool, _AfterWalkRigidBool, _BeforeSelfRigidBool, _AfterSelfRigidBool, _GetRigidBool, _SetRigidBool, _SetAttrOrCallRigidBool, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in do_command(self)
#     346                                                         self.CommandedSetVariablesList
#     347 						),
# --> 348                                                 self.CommandedValueVariablesList
#     349 					)
#     350
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in <lambda>(_CommanderClass__CommandedValueVariable)
#     344                                                                 __CommandedSetVariable
#     345 							),
# --> 346                                                         self.CommandedSetVariablesList
#     347 						),
#     348                                                 self.CommandedValueVariablesList
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Commander/__init__.pyc in <lambda>(_CommanderClass__CommandedSetVariable)
#     342                                                         lambda __CommandedSetVariable:
#     343 							__CommandedValueVariable.setAttrOrCall(
# --> 344                                                                 __CommandedSetVariable
#     345 							),
#     346                                                         self.CommandedSetVariablesList
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Itemizers/Setter/__init__.pyc in setAttrOrCall(self, _ItemVariable)
#    1710
#    1711                         #getattr
# -> 1712                         getattr(self,_ItemVariable)()
#    1713
#    1714
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Binder/__init__.pyc in switch_watch_superDo_brian(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Switcher/__init__.pyc in switch(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     269                 _InstanceVariable,
#     270                 *_LiargVariablesList,
# --> 271                 **_KwargVariablesDict
#     272 	)
#     273
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Binder/__init__.pyc in watch_superDo_brian(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Watcher/__init__.pyc in watch(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     105                 _InstanceVariable,
#     106                 *_LiargVariablesList,
# --> 107                 **_KwargVariablesDict
#     108 	)
#     109
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_brian(_InstanceVariable, _NeurongroupDict, _SynapsesDict, _ConnectVariable, _TraceDict, _MoniterTuple, _SpikesDict, _PyplotDict, _TimeQuantityStr, _PyplotBool, _StepTimeFloat, _DebugInt, _RecordBool, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Recorders/Brianer/__init__.pyc in do_brian(self)
#     253 				getattr(
#     254                                         self,
# --> 255                                         BrianedMethodKeyStr
#     256 				)()
#     257
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Recorders/Leaker/__init__.pyc in brianTrace(self)
#    1363
#    1364                 #call the base method
# -> 1365                 BaseClass.brianTrace(self)
#    1366
#    1367         def brianInput(self):
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Recorders/Brianer/__init__.pyc in brianTrace(self)
#     870
#     871                         #record
# --> 872                         self.record()
#     873
#     874                 #/####################/#
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Mimicker/__init__.pyc in superMimic_superDo_record(_InstanceVariable, _KeyVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Mimicker/__init__.pyc in mimic(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     115 		MimicOutputVariable=MimicUnBoundMethod(
#     116                                 _InstanceVariable,
# --> 117                                 *_LiargVariablesList
#     118 			)
#     119
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Recorders/Brianer/__init__.pyc in mimic_record(self)
#    1641
#    1642                 #base method
# -> 1643                 BaseClass.record(self)
#    1644
#    1645                 #debug
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in superDo_record(_InstanceVariable, _KeyVariable, *_LiargVariablesList, **_KwargVariablesDict)
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Classors/Doer/__init__.pyc in do(_InstanceVariable, *_LiargVariablesList, **_KwargVariablesDict)
#     321 		return DoWrapUnboundMethod(
#     322                         _InstanceVariable,
# --> 323                         *_LiargVariablesList
#     324 		)
#     325 #</DefineFunctions>
#
# /usr/local/lib/python2.7/site-packages/ShareYourSystem/Standards/Recorders/Recorder/__init__.pyc in do_record(self)
#     180 						SYS.deprefix(
#     181                                                         self.ManagementTagStr,
# --> 182                                                         RecordPrefixStr
#     183 						)
#     184 					)
#
# AttributeError: 'PredicterClass' object has no attribute 'U'

# %%
#/###################/#
# Simulate
#

MyPredicter.simulate(
    #SimulatingStopTimeFloat (ms here)
    500.
)

#/###################/#
# View
#

MyPredicter['/-Populations/|Sensor'].pyplot();
SYS.matplotlib.pyplot.show()
